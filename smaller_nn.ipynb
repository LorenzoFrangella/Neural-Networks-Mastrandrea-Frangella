# %% [markdown]
# Libraries required for developing the project

# %%
#@title Libraries required
# %%capture
# !pip install laion-clap
# !pip install transformers==4.30.2
# !pip install soundfile
# !pip install librosa
# !pip install torchlibrosa
# !pip install ftfy
# !pip install braceexpand
# !pip install webdataset
# !pip install wget
# !pip install wandb
# !pip install llvmlite
# !pip install scipy
# !pip install scikit-learn
# !pip install pandas
# !pip install h5py
# !pip install tqdm
# !pip install regex
# !pip install torch
# !pip install pytube
# !pip install pydub

# %%
#@title Import of CLAP for embedding
# %%capture
import laion_clap
import torch
from huggingface_hub import hf_hub_download
import librosa
import os
import numpy as np

model = laion_clap.CLAP_Module(enable_fusion=False, amodel= 'HTSAT-base').to(device='cuda')
dataset_path = hf_hub_download(repo_id="lukewys/laion_clap", filename="music_speech_audioset_epoch_15_esc_89.98.pt")
model.load_ckpt(dataset_path)
# quantization
def int16_to_float32(x):
    return (x / 32767.0).astype(np.float32)


def float32_to_int16(x):
    x = np.clip(x, a_min=-1., a_max=1.)
    return (x * 32767.).astype(np.int16)

# %%
#@title Instructions to load the code and the datase
pat = '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'
# !git clone https://{pat}@github.com/LorenzoFrangella/Neural-Networks-Mastrandrea-Frangella/
# !mv Neural-Networks-Mastrandrea-Frangella/download .
# !mv Neural-Networks-Mastrandrea-Frangella/tmp .
# !mv Neural-Networks-Mastrandrea-Frangella/new_balanced.csv .
# !mv Neural-Networks-Mastrandrea-Frangella/validation_set.csv .
# !mv Neural-Networks-Mastrandrea-Frangella/validation .
# !mv Neural-Networks-Mastrandrea-Frangella/class_labels_indices.csv .
# !mv Neural-Networks-Mastrandrea-Frangella/eval_segments.csv .
# !rm ./download/.DS_Store
# !rm ./validation/.DS_Store
# Out:
# fatal: destination path 'Neural-Networks-Mastrandrea-Frangella' already exists and is not an empty directory.
# mv: cannot stat 'Neural-Networks-Mastrandrea-Frangella/download': No such file or directory
# mv: cannot stat 'Neural-Networks-Mastrandrea-Frangella/tmp': No such file or directory
# mv: cannot stat 'Neural-Networks-Mastrandrea-Frangella/new_balanced.csv': No such file or directory
# mv: cannot stat 'Neural-Networks-Mastrandrea-Frangella/validation_set.csv': No such file or directory
# mv: cannot stat 'Neural-Networks-Mastrandrea-Frangella/validation': No such file or directory
# mv: cannot stat 'Neural-Networks-Mastrandrea-Frangella/class_labels_indices.csv': No such file or directory
# mv: cannot stat 'Neural-Networks-Mastrandrea-Frangella/eval_segments.csv': No such file or directory
# rm: cannot remove './download/.DS_Store': No such file or directory
# rm: cannot remove './validation/.DS_Store': No such file or directory

# %%
#@title Cleanup (!!!!!)
# !rm -rf ./download
# !rm -rf ./tmp
# !rm -rf ./validation
# !rm -rf Neural-Networks-Mastrandrea-Frangella/

# %%
#@title Utility functions to manage the data
from  pytube import YouTube
import os
from pydub import AudioSegment
import csv
import random
import math
import torch
import torchaudio

def cut_audio(input_file, start_time, end_time):
    audio = AudioSegment.from_file(input_file)
    audio = audio.set_frame_rate(32000)
    cut_audio = audio[start_time:end_time]
    cut_audio.export(input_file, format="mp3")

def get_mixture_audio(audio1,audio2):

    E1 = torch.square(torch.norm(audio1,p=2))
    E2 = torch.square(torch.norm(audio2,p=2))

    alpha = torch.sqrt(E1/E2)

    x = audio1 + alpha * audio2
    return x

def get_audio_clip(video_id, start, end, download=True,path='./download'):

    if download:

        if f"{video_id}.mp3" not in os.listdir(path):
            video_url = f"https://www.youtube.com/watch?v={video_id}"
            selected_video = YouTube(video_url)
            audio = selected_video.streams.filter(only_audio = True).first()
            path_dest = audio.download(path, filename=f"{video_id}.mp3")
            print(f"download:{video_id} in path: {path_dest}")
            cut_audio(path_dest, start*1000, end*1000)

        path_dest = f"{path}/{video_id}.mp3"

    else:

        if f"{video_id}.mp3" not in os.listdir(path):
            return ""

        else:
            path_dest = f"{path}/{video_id}.mp3"

    return path_dest

def download_all_dataset():
    with open("./Neural-Networks-Mastrandrea-Frangella/new_balanced.csv", mode ='r')as file:
        csvFile = csv.reader(file)
        for lines in csvFile:
            video_id = lines[0]
            start = lines[1]
            end = lines[2]
            try:
                get_audio_clip(video_id,float(start),float(end))
            except:
                continue

def get_random_files(directory, count=20):
    files = os.listdir(directory)
    random_files = random.sample(files, count)
    return random_files

def get_batch(batch_size,dataset_path,labels_file,modality):
    batch_size=batch_size*2
    random_samples = get_random_files(dataset_path,batch_size)
    half = int(batch_size/2)

    first_subset = random_samples[0:half]
    second_subset = random_samples[half:batch_size]

    labels_dict = {}

    with open(labels_file, mode ='r')as file:
        csvFile = csv.reader(file)
        for lines in csvFile:
            label = lines[4][1:-1]
            label = label.replace("[","")
            label = label.replace("]","")
            label = label.replace(",","")
            label = label.replace("'","")
            labels_dict[lines[0]]=[label]

    batch = []
    labels = []
    target = []



    for i in range(half):
        audio1,sample_rate1 = torchaudio.load(f"./download/{first_subset[i]}")
        audio2,sample_rate2 = torchaudio.load(f"./download/{second_subset[i]}")

        mixed = get_mixture_audio(audio1,audio2)

        # computing starting and ending frame for audio1
        start = random.randint(0,160000)
        end = start + 160000

        mixed = mixed[:,start:end]
        audio1 = audio1[:,start:end]

        target.append(audio1)

        batch.append(mixed)
        labels.append(labels_dict[first_subset[i][:-4]][0])

    batch = torch.stack(batch,dim=0)
    target = torch.stack(target,dim=0)

    if modality=="text":
        return (batch,target,labels,False)

    else:
        if random.uniform(0,1) > 0.5:
            labels = ["./download/"+elem for elem in first_subset]
            return (batch,target,labels,True)

    return (batch,target,labels,False)


def get_audio_metadata(video_id,path='./new_balanced.csv'):
  with open(path, mode='r') as file:
    # Create a CSV reader object
    csv_reader = csv.reader(file)
    for row in csv_reader:
      if row[0] == video_id:
        return row

def get_dict_of_classes():
  with open('class_labels_indices.csv', mode='r') as file:
    # Create a CSV reader object
        csv_reader = csv.reader(file)
        # Read and print each row of the CSV file
        classes_dict = {}
        labels = []
        for row in csv_reader:

            label = row[1]
            labels.append(label)

        classes = labels.copy()
        for elem in labels:
            #remove elem from classes
            classes.remove(elem)
            random_classes = random.sample(classes,5)
            #add elem from labels
            classes.append(elem)
            #shuffle of labels
            random.shuffle(classes)
            classes_dict[elem]=random_classes
  file_path = 'eval_segments.csv'
  with open(file_path, 'r') as file:
    reader = csv.reader(file)
    next(reader)
    next(reader)
    next(reader)
    video_dict = {}
    for row in reader:
        new_column = ""
        for i in range(3,len(row)):
            new_column += row[i]
            if(i != len(row)-1):
                new_column += ","
        row[3] = new_column.replace('"', '')
        row[3] = row[3].replace(' ', '')
        tokens = row[3].split(",")
        for elem in tokens:
            if elem not in video_dict:
                video_dict[elem] = []
                video_dict[elem].append(row[0])
            else:
                video_dict[elem].append(row[0])
  return video_dict,classes_dict

# %%
#@title Clean the dataset
# %%capture
import os
audios = os.listdir("./download")
import shutil


for audio_path in audios:
  audio_clip,w = torchaudio.load(f"./download/{audio_path}")
  if torch.norm(audio_clip,p=2) == 0:
    print(f"./download/{audio_path}")
    os.remove(f"./download/{audio_path}")
  if audio_clip.shape[1] != 320000:
    os.remove(f"./download/{audio_path}")
    print(f"./download/{audio_path}")

# %%
#@title Classes to Manage Audios
class Audioclip():
  def __init__(self,video_id,path="./download",file="./new_balanced.csv"):
    self.video_id = video_id
    info = get_audio_metadata(video_id,file)
    self.start, self.end, self.classes, self.labels = info[1],info[2],info[3],info[4]
    self.start = float(self.start)
    self.end = float(self.end)
    self.classes = self.classes.split(",")
    self.labels = self.labels.replace("[","").replace("]","").replace(",","").replace('"',"")

    if (video_id) not in os.listdir("./download"):
      path_dest = get_audio_clip(video_id,self.start,self.end,True,path)
    self.audioclip,self.sample_rate = torchaudio.load(path_dest)

class Mixedaudio():
  def __init__(self,audio1, audio2 ,path1 = "./download" ,path2="./download",file="./new_balanced.csv"):
    self.audio1 = Audioclip(audio1,path1,file)
    self.audio2 = Audioclip(audio2,path2,file)

    self.mixed_track = get_mixture_audio(self.audio1.audioclip,self.audio2.audioclip)


  def get_random_sample(self):
    start = random.randint(0,160000)
    end = start + 160000
    return (self.mixed_track[:,start:end],self.audio1.audioclip[:,start:end])

# %%
#@title Function to get the validation set
def get_validation_set(classes):
  video_dict,classes_dict = get_dict_of_classes()
  video_keys = list(video_dict.keys())
  j = 0
  m = []
  target = []
  labels = []
  for key in video_keys:
    if j >= classes:
      break
    random_classes = classes_dict[key]
    for c in random_classes:

      while True:
        s1 = random.sample(video_dict[key],1)[0]
        s2 = random.sample(video_dict[c],1)[0]
        try:
          mix = Mixedaudio(s1,s2,"./validation","./validation","./eval_segments.csv")
          mixed,target_cutted = mix.get_random_sample()
          target.append(target_cutted)
          m.append(mixed)
          labels.append(mix.audio1.labels)
          break
        except:
          continue



    j+=1
  return m,target,labels
#random.seed(12345)
#mixed, target, labels = get_validation_set(10)

# %%
# !zip -r ./validation.zip /content/validation

# %%
#@title Utility Functions for the Neural Network
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchlibrosa.stft import STFT, ISTFT, magphase
import numpy as np

stft = STFT(n_fft=1024,
            hop_length=320,
            win_length=1024,
            window='hann',
            center=True,
            pad_mode='reflect',
            freeze_parameters=True).to(device='cuda')

istft = ISTFT(
            n_fft=1024,
            hop_length=320,
            win_length=1024,
            window='hann',
            center=True,
            pad_mode='reflect',
            freeze_parameters=True
        ).to(device='cuda')

def init_bn(bn):
    bn.bias.data.fill_(0.0)
    bn.weight.data.fill_(1.0)

def init_layer(layer):
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, "bias"):
        if layer.bias is not None:
            layer.bias.data.fill_(0.0)

def from_audio_to_spectogram(audios):
    magnitudes = []
    cosines = []
    sines = []
    for i in range(audios.shape[1]):

        (real,imag) = stft(audios[:,i,:])
        mag = torch.clamp(real ** 2 + imag ** 2, 1e-8, np.inf) ** 0.5
        cos = real / mag
        sin = imag / mag
        magnitudes.append(mag)
        cosines.append(cos)
        sines.append(sin)
    mags = torch.cat(magnitudes, dim=1)
    coss = torch.cat(cosines, dim=1)
    sins = torch.cat(sines, dim=1)

    return mags,coss,sins

# %%
#@title Film module
class FilmModule(nn.Module):
    def __init__(self,input_size,output_size):
        super(FilmModule, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.l1 = nn.Linear(input_size, output_size * 2)
        self.l2 = nn.Linear(output_size * 2, output_size)
        self.init_weights()

    def init_weights(self):
        init_layer(self.l1)
        init_layer(self.l2)

    def forward(self,data,embedding_vector):
        x = F.relu(self.l1(embedding_vector))
        x = F.relu(self.l2(x))
        dim = x.shape
        x = data + x[...,None,None]

        return x

# %%
#@title Encoder Block
class EncoderBlock(nn.Module):
    def __init__(self,input_channels, output_channels, embedding_size, momentum,downsample):
        super(EncoderBlock, self).__init__()
        self.downsample = downsample
        self.Film1 = FilmModule(embedding_size,input_channels)
        self.Film2 = FilmModule(embedding_size,output_channels)


        self.bn1 = nn.BatchNorm2d(input_channels,momentum=momentum)

        self.conv1 = nn.Conv2d(
            in_channels=input_channels,
            out_channels=output_channels,
            kernel_size=(3,3),
            stride=(1,1),
            dilation=(1,1),
            padding=(1,1),
            bias=False
            )

        self.bn2 = nn.BatchNorm2d(output_channels,momentum=momentum)

        self.conv2 = nn.Conv2d(
            in_channels=output_channels,
            out_channels=output_channels,
            kernel_size=(3,3),
            stride=(1,1),
            dilation=(1,1),
            padding=(1,1),
            bias=False
        )

        if input_channels != output_channels:
            self.residual_convolution = nn.Conv2d(
                in_channels=input_channels,
                out_channels=output_channels,
                kernel_size=(1,1),
                stride=(1,1),
                padding=(0,0),
            )
            self.has_residual_connection = True
        else:
            self.has_residual_connection = False

        self.init_weights()


    def init_weights(self):
        init_bn(self.bn1)
        init_bn(self.bn2)
        init_layer(self.conv1)
        init_layer(self.conv2)

        if self.has_residual_connection:
            init_layer(self.residual_convolution)



    def forward(self,input_tensor,embedding_vector):

        x = self.bn1(input_tensor)
        x = self.Film1(x,embedding_vector)
        x = F.leaky_relu(x,negative_slope=0.01)
        x = self.conv1(x)
        x = self.bn2(x)
        x = self.Film2(x,embedding_vector)
        x = F.leaky_relu(x,negative_slope=0.01)
        x = self.conv2(x)

        if self.has_residual_connection:
            y = self.residual_convolution(input_tensor)
            x = x + y

        x_pool = F.avg_pool2d(x,self.downsample)

        return x, x_pool

# %%
#@title Decoder Block
class DecoderBlock(nn.Module):

    def __init__(self,input_size, output_size,embedding_size,momentum,upsample):
        super(DecoderBlock, self).__init__()
        self.upsample = upsample

        self.conv1 = torch.nn.ConvTranspose2d(
            in_channels=input_size,
            out_channels=output_size,
            kernel_size=self.upsample,
            stride=self.upsample,
            padding=(0,0),
            bias=False,
            dilation=(1,1)

        )

        self.bn1 = nn.BatchNorm2d(input_size,momentum=momentum)

        #self.conv_block2 = ConvBlockRes(
        #    out_channels * 2, out_channels, kernel_size, momentum, has_film,

        self.Film1 = FilmModule(embedding_size,input_size)
        self.Film2 = FilmModule(embedding_size,output_size*2)
        self.Film3 = FilmModule(embedding_size,output_size)

        self.bn2 = nn.BatchNorm2d(output_size*2,momentum=momentum)
        self.bn3 = nn.BatchNorm2d(output_size,momentum=momentum)

        self.conv2 = nn.Conv2d(
            in_channels=output_size*2,
            out_channels=output_size,
            kernel_size=(3,3),
            stride=(1,1),
            dilation=(1,1),
            padding=(1,1),
            bias=False
        )

        self.conv3 = nn.Conv2d(
            in_channels=output_size,
            out_channels=output_size,
            kernel_size=(3,3),
            stride=(1,1),
            dilation=(1,1),
            padding=(1,1),
            bias=False
        )

        self.residual_convolution = nn.Conv2d(
                in_channels=output_size*2,
                out_channels=output_size,
                kernel_size=(1,1),
                stride=(1,1),
                padding=(0,0),
            )
        self.has_residual_connection = True

        self.bn4 = nn.BatchNorm2d(input_size,momentum=momentum)




        self.init_weights()

    def init_weights(self):
        init_bn(self.bn1)
        init_bn(self.bn2)
        init_bn(self.bn3)

        init_layer(self.conv1)
        init_layer(self.conv2)
        init_layer(self.conv3)

        if self.has_residual_connection:
            init_layer(self.residual_convolution)

    def forward(self,input_tensor,concat_tensor,embedding_vector):
        x = self.bn1(input_tensor)
        x = self.Film1(x,embedding_vector)
        x = F.leaky_relu(x)

        x = self.conv1(x)

        x = torch.cat((x,concat_tensor), dim=1)
        x_res = x
        x = self.bn2(x)
        x = self.Film2(x,embedding_vector)
        x = F.leaky_relu(x,negative_slope=0.01)
        x = self.conv2(x)
        x = self.bn3(x)
        x = self.Film3(x,embedding_vector)
        x = F.leaky_relu(x,negative_slope=0.01)
        x = self.conv3(x)
        if self.has_residual_connection:
            y = self.residual_convolution(x_res)



            x = x + y

        return x

# %%
#@title ResUNet
class ResUnet(nn.Module):

    def __init__(self, input_size, output_size):
        super(ResUnet, self).__init__()

        self.input_size = input_size;
        self.output_size = output_size;

        self.momentum = 0.01


        # instanziare la preconv che è una conv2d

        # definire la classe degli encoder block
        # definire la classe dei decoder block

        self.batch_norm0 = nn.BatchNorm2d(513,momentum=self.momentum)
        self.preconvolution = nn.Conv2d(
            in_channels=input_size,
            out_channels=32,
            kernel_size=(1,1),
            stride=(1,1),
            padding=(0,0),
            bias=True
        )

        self.EncoderBlock1 = EncoderBlock(
            input_channels=32,
            output_channels=32,
            downsample=(2,2),
            embedding_size=512,
            momentum=self.momentum
        )

        self.EncoderBlock2 = EncoderBlock(
            input_channels=32,
            output_channels=64,
            downsample=(2,2),
            embedding_size=512,
            momentum=self.momentum
        )

        self.EncoderBlock3 = EncoderBlock(
            input_channels=64,
            output_channels=96,
            downsample=(2,2),
            embedding_size=512,
            momentum=self.momentum
        )

        self.EncoderBlock4 = EncoderBlock(
            input_channels=96,
            output_channels=96,
            downsample=(1,2),
            embedding_size=512,
            momentum=self.momentum
        )

        self.EncoderBlock_center = EncoderBlock(
            input_channels=96,
            output_channels=96,
            downsample=(1,1),
            momentum=0.01,
            embedding_size=512
        )

        self.DecoderBlock1 = DecoderBlock(
            input_size=96,
            output_size=96,
            embedding_size= 512,
            momentum=self.momentum,
            upsample=(1,2)
            )

        self.DecoderBlock2 = DecoderBlock(
            input_size=96,
            output_size=96,
            embedding_size= 512,
            momentum=self.momentum,
            upsample=(2,2)
            )

        self.DecoderBlock3 = DecoderBlock(
            input_size=96,
            output_size=64,
            embedding_size= 512,
            momentum=self.momentum,
            upsample=(2,2)
            )

        self.DecoderBlock4 = DecoderBlock(
            input_size=64,
            output_size= 32,
            embedding_size= 512,
            momentum=self.momentum,
            upsample=(2,2)
            )


        self.after_conv = nn.Conv2d(
            in_channels=32,
            out_channels=2*3,
            kernel_size=(1, 1),
            stride=(1, 1),
            padding=(0, 0),
            bias=True,
        )


        self.init_weights()
    def init_weights(self):
        init_bn(self.batch_norm0)
        init_layer(self.preconvolution)
        init_layer(self.after_conv)

    def forward(self,input,embedding_vector):
        #x -->mag
        #coss--->coss
        #sins--->sins
        audio_length = input.shape[-1]
        audios = input.clone()
        mags,coss,sins = from_audio_to_spectogram(audios)
        x = mags
        x = x.transpose(1,3)
        x = self.batch_norm0(x)
        x = x.transpose(1,3)
        origin_len = x.shape[2]
        pad_len = (int(np.ceil(x.shape[2] / 2**5)) * (2**5)- origin_len)
        x = F.pad(x, pad=(0, 0, 0, pad_len))
        x = x[:,:,:,0:-1]
        x = self.preconvolution(x)

        x1, x1_pool = self.EncoderBlock1(x,embedding_vector)
        x2, x2_pool = self.EncoderBlock2(x1_pool,embedding_vector)
        x3, x3_pool = self.EncoderBlock3(x2_pool,embedding_vector)
        x4, x4_pool = self.EncoderBlock4(x3_pool,embedding_vector)
        x_c,x_c_pool = self.EncoderBlock_center(x4_pool,embedding_vector)
        x5 = self.DecoderBlock1(x_c,x4,embedding_vector)
        x6 = self.DecoderBlock2(x5,x3,embedding_vector)
        x7 = self.DecoderBlock3(x6,x2,embedding_vector)
        x8 = self.DecoderBlock4(x7,x1,embedding_vector)
        x = self.after_conv(x8)

        x = F.pad(x, pad=(0, 1))
        x = x[:, :, 0:origin_len, :]
        batch_size,_,time_steps,frequency_bins = x.shape
        x = x.reshape(
            batch_size,   #batch size
            1,   #target audio
            2,   #num channels
            3,   #magnitude, cos, sin
            time_steps, #time_steps
            frequency_bins, #frequency bins
        )
        mask_mag = torch.sigmoid(x[:, :, :, 0, :, :]) # get the magnitude mask
        _mask_real = torch.tanh(x[:, :, :, 1, :, :])  # get the real component mask
        _mask_imag = torch.tanh(x[:, :, :, 2, :, :])  # get the imaginary component mask
        #mask_mag, mask_cos, mask_sin = magphase(_mask_real, _mask_imag)# get the fourier transform of the mask
        # apply the filtering functions to the cosine
        # mask_mag = (_mask_real ** 2 + _mask_imag ** 2) ** 0.5
        mask_cos = _mask_real / torch.clamp(_mask_imag, 1e-10, np.inf)
        mask_sin = _mask_imag / torch.clamp(_mask_imag, 1e-10, np.inf)
        out_cos = (
            coss[:, None, :, :, :] * mask_cos - sins[:, None, :, :, :] * mask_sin
        )

        # apply the filtering function to the sine

        out_sin = (
            sins[:, None, :, :, :] * mask_cos + coss[:, None, :, :, :] * mask_sin
        )
        #apply the filtering function to the magnitude

        out_mag = F.relu(mags[:, None, :, :, :] * mask_mag)
        out_real = torch.mul(out_mag , out_cos)
        out_imag = torch.mul(out_mag , out_sin)

        out_real = out_real.reshape(2*batch_size,1,time_steps,frequency_bins)
        out_imag = out_imag.reshape(2*batch_size,1,time_steps,frequency_bins)
        x = istft(out_real, out_imag, audio_length)
        waveform = x.reshape(batch_size,2,audio_length)
        return waveform

# %%
#@title Loss Implementation
class LossAudio(nn.Module):
  def __init__(self):
    super(LossAudio, self).__init__()
  def forward(self,s,s_hat):
    loss = torch.abs(s-s_hat)
    return loss.mean()

# %%
#@title Network definition with loss and optimizer
class AudioSep(nn.Module):
  def __init__(self,input_size, output_size):
      super(AudioSep, self).__init__()
      self.model = ResUnet(input_size,output_size)
      self.loss = nn.L1Loss()
      self.optimizer = torch.optim.AdamW(params=self.model.parameters(),
                lr=1e-5,
                betas=(0.9, 0.999),
                eps=1e-08,
                weight_decay=0.0,
                amsgrad=True)

  def forward(self,x):
    pass

# %%
#@title Add Google drive to save checkpoints
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/MyDrive/trained_models
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/MyDrive/trained_models’: File exists

# %%
rete = AudioSep(2,2).to(device='cuda')

# %%
#@title Save the weights
path_checkpoint = "/content/drive/MyDrive/trained_models/neural_networks_smaller.pt"
#torch.save(rete.state_dict(), path_checkpoint)

# %%
#@title Load the checkpoints

rete.load_state_dict(torch.load(path_checkpoint))
# Out:
# <All keys matched successfully>

# %%
training_steps = 11000
batch_size = 8
torch.autograd.set_detect_anomaly(True)
random.seed(1234)
batch,target,labels,isAudio = get_batch(batch_size,"./download","./new_balanced.csv","text")
for i in range(training_steps):
  audio_embeddings = model.get_text_embedding(labels,use_tensor=True).to(device="cuda")
  batch = batch.to(device="cuda")
  target = target.to(device="cuda")
  output = rete.model(batch,audio_embeddings)
  #print(target[0])
  if (i%100) == 0:
    print("saving a training checkpoint in drive")
    torch.save(rete.state_dict(), path_checkpoint)
  loss = rete.loss(output,target)
  print("iteration",i,loss)
  # Backward and optimize
  rete.optimizer.zero_grad()
  loss.backward()
  rete.optimizer.step()
# Out:
# Output streaming troncato alle ultime 5000 righe.
# iteration 4183 tensor(2.8734, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4184 tensor(2.8729, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4185 tensor(2.8724, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4186 tensor(2.8718, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4187 tensor(2.8706, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4188 tensor(2.8701, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4189 tensor(2.8695, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4190 tensor(2.8690, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4191 tensor(2.8684, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4192 tensor(2.8678, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4193 tensor(2.8673, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4194 tensor(2.8668, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4195 tensor(2.8662, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4196 tensor(2.8657, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4197 tensor(2.8651, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4198 tensor(2.8645, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4199 tensor(2.8640, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 4200 tensor(2.8635, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4201 tensor(2.8629, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4202 tensor(2.8624, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4203 tensor(2.8618, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4204 tensor(2.8613, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4205 tensor(2.8607, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4206 tensor(2.8602, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4207 tensor(2.8597, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4208 tensor(2.8591, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4209 tensor(2.8586, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4210 tensor(2.8580, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4211 tensor(2.8575, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4212 tensor(2.8569, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4213 tensor(2.8564, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4214 tensor(2.8559, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4215 tensor(2.8553, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4216 tensor(2.8548, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4217 tensor(2.8542, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4218 tensor(2.8537, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4219 tensor(2.8532, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4220 tensor(2.8526, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4221 tensor(2.8521, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4222 tensor(2.8515, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4223 tensor(2.8510, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4224 tensor(2.8505, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4225 tensor(2.8499, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4226 tensor(2.8494, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4227 tensor(2.8489, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4228 tensor(2.8483, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4229 tensor(2.8478, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4230 tensor(2.8472, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4231 tensor(2.8467, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4232 tensor(2.8462, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4233 tensor(2.8456, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4234 tensor(2.8451, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4235 tensor(2.8446, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4236 tensor(2.8440, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4237 tensor(2.8435, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4238 tensor(2.8430, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4239 tensor(2.8424, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4240 tensor(2.8419, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4241 tensor(2.8414, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4242 tensor(2.8408, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4243 tensor(2.8403, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4244 tensor(2.8398, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4245 tensor(2.8392, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4246 tensor(2.8387, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4247 tensor(2.8382, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4248 tensor(2.8376, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4249 tensor(2.8371, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4250 tensor(2.8366, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4251 tensor(2.8360, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4252 tensor(2.8355, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4253 tensor(2.8350, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4254 tensor(2.8344, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4255 tensor(2.8339, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4256 tensor(2.8334, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4257 tensor(2.8329, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4258 tensor(2.8323, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4259 tensor(2.8318, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4260 tensor(2.8313, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4261 tensor(2.8307, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4262 tensor(2.8302, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4263 tensor(2.8297, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4264 tensor(2.8292, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4265 tensor(2.8286, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4266 tensor(2.8281, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4267 tensor(2.8276, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4268 tensor(2.8271, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4269 tensor(2.8265, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4270 tensor(2.8260, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4271 tensor(2.8255, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4272 tensor(2.8250, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4273 tensor(2.8244, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4274 tensor(2.8239, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4275 tensor(2.8234, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4276 tensor(2.8228, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4277 tensor(2.8223, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4278 tensor(2.8218, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4279 tensor(2.8213, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4280 tensor(2.8207, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4281 tensor(2.8202, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4282 tensor(2.8197, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4283 tensor(2.8192, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4284 tensor(2.8186, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4285 tensor(2.8181, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4286 tensor(2.8176, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4287 tensor(2.8170, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4288 tensor(2.8165, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4289 tensor(2.8160, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4290 tensor(2.8155, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4291 tensor(2.8149, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4292 tensor(2.8144, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4293 tensor(2.8139, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4294 tensor(2.8134, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4295 tensor(2.8128, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4296 tensor(2.8123, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4297 tensor(2.8118, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4298 tensor(2.8113, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4299 tensor(2.8107, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 4300 tensor(2.8102, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4301 tensor(2.8097, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4302 tensor(2.8092, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4303 tensor(2.8087, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4304 tensor(2.8081, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4305 tensor(2.8076, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4306 tensor(2.8071, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4307 tensor(2.8066, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4308 tensor(2.8060, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4309 tensor(2.8055, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4310 tensor(2.8050, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4311 tensor(2.8045, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4312 tensor(2.8040, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4313 tensor(2.8034, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4314 tensor(2.8029, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4315 tensor(2.8024, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4316 tensor(2.8019, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4317 tensor(2.8013, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4318 tensor(2.8008, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4319 tensor(2.8003, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4320 tensor(2.7998, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4321 tensor(2.7993, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4322 tensor(2.7988, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4323 tensor(2.7982, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4324 tensor(2.7977, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4325 tensor(2.7972, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4326 tensor(2.7967, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4327 tensor(2.7962, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4328 tensor(2.7956, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4329 tensor(2.7951, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4330 tensor(2.7946, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4331 tensor(2.7941, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4332 tensor(2.7936, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4333 tensor(2.7931, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4334 tensor(2.7925, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4335 tensor(2.7920, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4336 tensor(2.7915, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4337 tensor(2.7910, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4338 tensor(2.7905, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4339 tensor(2.7900, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4340 tensor(2.7895, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4341 tensor(2.7889, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4342 tensor(2.7884, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4343 tensor(2.7879, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4344 tensor(2.7874, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4345 tensor(2.7869, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4346 tensor(2.7864, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4347 tensor(2.7858, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4348 tensor(2.7853, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4349 tensor(2.7848, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4350 tensor(2.7843, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4351 tensor(2.7838, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4352 tensor(2.7833, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4353 tensor(2.7828, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4354 tensor(2.7822, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4355 tensor(2.7817, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4356 tensor(2.7812, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4357 tensor(2.7808, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4358 tensor(2.7802, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4359 tensor(2.7797, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4360 tensor(2.7792, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4361 tensor(2.7787, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4362 tensor(2.7781, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4363 tensor(2.7776, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4364 tensor(2.7771, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4365 tensor(2.7766, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4366 tensor(2.7761, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4367 tensor(2.7756, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4368 tensor(2.7751, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4369 tensor(2.7746, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4370 tensor(2.7741, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4371 tensor(2.7736, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4372 tensor(2.7730, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4373 tensor(2.7725, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4374 tensor(2.7720, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4375 tensor(2.7715, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4376 tensor(2.7710, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4377 tensor(2.7705, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4378 tensor(2.7700, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4379 tensor(2.7695, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4380 tensor(2.7690, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4381 tensor(2.7685, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4382 tensor(2.7680, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4383 tensor(2.7675, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4384 tensor(2.7670, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4385 tensor(2.7665, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4386 tensor(2.7660, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4387 tensor(2.7654, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4388 tensor(2.7649, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4389 tensor(2.7644, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4390 tensor(2.7639, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4391 tensor(2.7634, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4392 tensor(2.7629, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4393 tensor(2.7624, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4394 tensor(2.7619, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4395 tensor(2.7614, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4396 tensor(2.7609, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4397 tensor(2.7604, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4398 tensor(2.7599, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4399 tensor(2.7594, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 4400 tensor(2.7589, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4401 tensor(2.7584, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4402 tensor(2.7579, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4403 tensor(2.7574, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4404 tensor(2.7569, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4405 tensor(2.7564, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4406 tensor(2.7559, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4407 tensor(2.7554, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4408 tensor(2.7549, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4409 tensor(2.7544, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4410 tensor(2.7539, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4411 tensor(2.7534, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4412 tensor(2.7529, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4413 tensor(2.7524, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4414 tensor(2.7519, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4415 tensor(2.7515, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4416 tensor(2.7510, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4417 tensor(2.7505, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4418 tensor(2.7500, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4419 tensor(2.7495, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4420 tensor(2.7490, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4421 tensor(2.7485, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4422 tensor(2.7480, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4423 tensor(2.7475, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4424 tensor(2.7294, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4425 tensor(2.7289, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4426 tensor(2.7285, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4427 tensor(2.7280, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4428 tensor(2.7275, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4429 tensor(2.7270, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4430 tensor(2.7265, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4431 tensor(2.7260, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4432 tensor(2.7255, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4433 tensor(2.7250, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4434 tensor(2.7245, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4435 tensor(2.7240, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4436 tensor(2.7235, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4437 tensor(2.7231, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4438 tensor(2.7226, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4439 tensor(2.7221, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4440 tensor(2.7216, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4441 tensor(2.7211, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4442 tensor(2.7206, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4443 tensor(2.7201, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4444 tensor(2.7196, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4445 tensor(2.7191, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4446 tensor(2.7187, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4447 tensor(2.7182, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4448 tensor(2.7177, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4449 tensor(2.7172, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4450 tensor(2.7167, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4451 tensor(2.7162, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4452 tensor(2.7157, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4453 tensor(2.7153, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4454 tensor(2.7148, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4455 tensor(2.7143, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4456 tensor(2.7138, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4457 tensor(2.7133, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4458 tensor(2.7129, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4459 tensor(2.7124, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4460 tensor(2.7119, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4461 tensor(2.7114, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4462 tensor(2.7109, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4463 tensor(2.7105, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4464 tensor(2.7100, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4465 tensor(2.7095, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4466 tensor(2.7090, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4467 tensor(2.7085, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4468 tensor(2.7081, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4469 tensor(2.7076, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4470 tensor(2.7071, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4471 tensor(2.7066, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4472 tensor(2.7061, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4473 tensor(2.7058, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4474 tensor(2.7052, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4475 tensor(2.7047, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4476 tensor(2.7042, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4477 tensor(2.7038, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4478 tensor(2.7033, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4479 tensor(2.7028, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4480 tensor(2.7023, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4481 tensor(2.7019, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4482 tensor(2.7014, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4483 tensor(2.7009, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4484 tensor(2.7005, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4485 tensor(2.7000, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4486 tensor(2.6995, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4487 tensor(2.6990, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4488 tensor(2.6986, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4489 tensor(2.6981, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4490 tensor(2.6976, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4491 tensor(2.6971, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4492 tensor(2.6967, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4493 tensor(2.6962, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4494 tensor(2.6957, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4495 tensor(2.6953, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4496 tensor(2.6948, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4497 tensor(2.6943, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4498 tensor(2.6938, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4499 tensor(2.6934, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 4500 tensor(2.6929, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4501 tensor(2.6924, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4502 tensor(2.6920, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4503 tensor(2.6915, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4504 tensor(2.6910, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4505 tensor(2.6906, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4506 tensor(2.6901, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4507 tensor(2.6896, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4508 tensor(2.6892, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4509 tensor(2.6887, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4510 tensor(2.6882, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4511 tensor(2.6878, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4512 tensor(2.6874, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4513 tensor(2.6869, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4514 tensor(2.6864, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4515 tensor(2.6859, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4516 tensor(2.6855, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4517 tensor(2.6850, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4518 tensor(2.6845, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4519 tensor(2.6840, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4520 tensor(2.6836, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4521 tensor(2.6831, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4522 tensor(2.6826, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4523 tensor(2.6822, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4524 tensor(2.6817, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4525 tensor(2.6812, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4526 tensor(2.6808, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4527 tensor(2.6803, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4528 tensor(2.6798, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4529 tensor(2.6794, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4530 tensor(2.6789, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4531 tensor(2.6784, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4532 tensor(2.6780, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4533 tensor(2.6775, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4534 tensor(2.6770, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4535 tensor(2.6766, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4536 tensor(2.6761, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4537 tensor(2.6757, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4538 tensor(2.6752, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4539 tensor(2.6747, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4540 tensor(2.6743, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4541 tensor(2.6738, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4542 tensor(2.6733, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4543 tensor(2.6729, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4544 tensor(2.6724, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4545 tensor(2.6720, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4546 tensor(2.6715, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4547 tensor(2.6710, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4548 tensor(2.6706, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4549 tensor(2.6701, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4550 tensor(2.6696, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4551 tensor(2.6692, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4552 tensor(2.6687, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4553 tensor(2.6683, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4554 tensor(2.6678, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4555 tensor(2.6673, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4556 tensor(2.6669, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4557 tensor(2.6664, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4558 tensor(2.6660, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4559 tensor(2.6655, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4560 tensor(2.6650, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4561 tensor(2.6646, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4562 tensor(2.6641, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4563 tensor(2.6637, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4564 tensor(2.6632, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4565 tensor(2.6627, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4566 tensor(2.6623, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4567 tensor(2.6618, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4568 tensor(2.6614, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4569 tensor(2.6609, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4570 tensor(2.6605, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4571 tensor(2.6600, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4572 tensor(2.6595, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4573 tensor(2.6591, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4574 tensor(2.6586, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4575 tensor(2.6582, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4576 tensor(2.6577, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4577 tensor(2.6572, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4578 tensor(2.6574, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4579 tensor(2.6569, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4580 tensor(2.6563, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4581 tensor(2.6554, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4582 tensor(2.6550, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4583 tensor(2.6545, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4584 tensor(2.6541, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4585 tensor(2.6536, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4586 tensor(2.6532, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4587 tensor(2.6527, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4588 tensor(2.6522, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4589 tensor(2.6518, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4590 tensor(2.6513, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4591 tensor(2.6509, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4592 tensor(2.6507, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4593 tensor(2.6502, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4594 tensor(2.6495, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4595 tensor(2.6491, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4596 tensor(2.6486, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4597 tensor(2.6482, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4598 tensor(2.6477, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4599 tensor(2.6473, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 4600 tensor(2.6468, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4601 tensor(2.6464, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4602 tensor(2.6459, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4603 tensor(2.6454, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4604 tensor(2.6450, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4605 tensor(2.6445, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4606 tensor(2.6441, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4607 tensor(2.6436, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4608 tensor(2.6432, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4609 tensor(2.6427, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4610 tensor(2.6423, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4611 tensor(2.6418, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4612 tensor(2.6414, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4613 tensor(2.6409, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4614 tensor(2.6405, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4615 tensor(2.6400, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4616 tensor(2.6396, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4617 tensor(2.6391, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4618 tensor(2.6387, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4619 tensor(2.6382, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4620 tensor(2.6378, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4621 tensor(2.6373, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4622 tensor(2.6369, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4623 tensor(2.6364, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4624 tensor(2.6360, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4625 tensor(2.6355, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4626 tensor(2.6351, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4627 tensor(2.6346, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4628 tensor(2.6342, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4629 tensor(2.6338, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4630 tensor(2.6333, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4631 tensor(2.6329, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4632 tensor(2.6324, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4633 tensor(2.6320, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4634 tensor(2.6315, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4635 tensor(2.6311, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4636 tensor(2.6306, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4637 tensor(2.6302, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4638 tensor(2.6299, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4639 tensor(2.6293, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4640 tensor(2.6289, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4641 tensor(2.6284, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4642 tensor(2.6280, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4643 tensor(2.6275, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4644 tensor(2.6271, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4645 tensor(2.6266, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4646 tensor(2.6262, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4647 tensor(2.6257, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4648 tensor(2.6253, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4649 tensor(2.6249, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4650 tensor(2.6244, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4651 tensor(2.6240, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4652 tensor(2.6235, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4653 tensor(2.6231, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4654 tensor(2.6226, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4655 tensor(2.6222, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4656 tensor(2.6218, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4657 tensor(2.6213, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4658 tensor(2.6209, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4659 tensor(2.6204, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4660 tensor(2.6200, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4661 tensor(2.6196, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4662 tensor(2.6191, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4663 tensor(2.6187, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4664 tensor(2.6182, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4665 tensor(2.6178, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4666 tensor(2.6174, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4667 tensor(2.6169, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4668 tensor(2.6165, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4669 tensor(2.6160, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4670 tensor(2.6156, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4671 tensor(2.6152, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4672 tensor(2.6147, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4673 tensor(2.6143, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4674 tensor(2.6139, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4675 tensor(2.6134, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4676 tensor(2.6130, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4677 tensor(2.6125, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4678 tensor(2.6121, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4679 tensor(2.6117, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4680 tensor(2.6113, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4681 tensor(2.6108, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4682 tensor(2.6104, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4683 tensor(2.6099, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4684 tensor(2.6095, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4685 tensor(2.6091, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4686 tensor(2.6086, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4687 tensor(2.6082, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4688 tensor(2.6078, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4689 tensor(2.6073, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4690 tensor(2.6069, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4691 tensor(2.6065, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4692 tensor(2.6060, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4693 tensor(2.6056, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4694 tensor(2.6052, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4695 tensor(2.6047, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4696 tensor(2.6043, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4697 tensor(2.6039, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4698 tensor(2.6034, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4699 tensor(2.6030, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 4700 tensor(2.6026, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4701 tensor(2.6021, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4702 tensor(2.6017, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4703 tensor(2.6013, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4704 tensor(2.6008, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4705 tensor(2.6004, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4706 tensor(2.6000, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4707 tensor(2.5995, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4708 tensor(2.5991, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4709 tensor(2.5987, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4710 tensor(2.5982, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4711 tensor(2.5978, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4712 tensor(2.5974, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4713 tensor(2.5969, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4714 tensor(2.5965, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4715 tensor(2.5961, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4716 tensor(2.5957, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4717 tensor(2.5952, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4718 tensor(2.5948, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4719 tensor(2.5944, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4720 tensor(2.5939, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4721 tensor(2.5935, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4722 tensor(2.5931, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4723 tensor(2.5927, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4724 tensor(2.5922, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4725 tensor(2.5918, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4726 tensor(2.5914, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4727 tensor(2.5909, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4728 tensor(2.5905, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4729 tensor(2.5901, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4730 tensor(2.5897, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4731 tensor(2.5892, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4732 tensor(2.5888, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4733 tensor(2.5884, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4734 tensor(2.5880, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4735 tensor(2.5875, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4736 tensor(2.5871, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4737 tensor(2.5867, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4738 tensor(2.5862, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4739 tensor(2.5858, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4740 tensor(2.5854, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4741 tensor(2.5850, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4742 tensor(2.5845, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4743 tensor(2.5841, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4744 tensor(2.5837, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4745 tensor(2.5833, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4746 tensor(2.5828, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4747 tensor(2.5824, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4748 tensor(2.5820, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4749 tensor(2.5816, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4750 tensor(2.5811, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4751 tensor(2.5807, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4752 tensor(2.5803, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4753 tensor(2.5798, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4754 tensor(2.5794, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4755 tensor(2.5790, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4756 tensor(2.5786, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4757 tensor(2.5781, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4758 tensor(2.5777, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4759 tensor(2.5773, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4760 tensor(2.5769, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4761 tensor(2.5764, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4762 tensor(2.5760, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4763 tensor(2.5756, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4764 tensor(2.5752, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4765 tensor(2.5747, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4766 tensor(2.5743, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4767 tensor(2.5739, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4768 tensor(2.5735, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4769 tensor(2.5730, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4770 tensor(2.5726, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4771 tensor(2.5722, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4772 tensor(2.5718, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4773 tensor(2.5714, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4774 tensor(2.5709, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4775 tensor(2.5705, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4776 tensor(2.5701, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4777 tensor(2.5697, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4778 tensor(2.5692, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4779 tensor(2.5688, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4780 tensor(2.5684, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4781 tensor(2.5680, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4782 tensor(2.5675, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4783 tensor(2.5671, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4784 tensor(2.5667, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4785 tensor(2.5663, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4786 tensor(2.5658, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4787 tensor(2.5654, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4788 tensor(2.5650, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4789 tensor(2.5646, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4790 tensor(2.5642, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4791 tensor(2.5637, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4792 tensor(2.5633, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4793 tensor(2.5629, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4794 tensor(2.5625, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4795 tensor(2.5621, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4796 tensor(2.5616, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4797 tensor(2.5612, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4798 tensor(2.5608, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4799 tensor(2.5604, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 4800 tensor(2.5600, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4801 tensor(2.5595, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4802 tensor(2.5591, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4803 tensor(2.5587, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4804 tensor(2.5583, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4805 tensor(2.5579, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4806 tensor(2.5574, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4807 tensor(2.5570, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4808 tensor(2.5566, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4809 tensor(2.5562, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4810 tensor(2.5558, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4811 tensor(2.5554, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4812 tensor(2.5549, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4813 tensor(2.5545, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4814 tensor(2.5541, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4815 tensor(2.5537, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4816 tensor(2.5533, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4817 tensor(2.5528, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4818 tensor(2.5524, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4819 tensor(2.5520, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4820 tensor(2.5516, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4821 tensor(2.5512, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4822 tensor(2.5508, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4823 tensor(2.5503, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4824 tensor(2.5499, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4825 tensor(2.5495, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4826 tensor(2.5491, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4827 tensor(2.5487, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4828 tensor(2.5483, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4829 tensor(2.5479, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4830 tensor(2.5474, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4831 tensor(2.5470, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4832 tensor(2.5466, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4833 tensor(2.5462, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4834 tensor(2.5458, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4835 tensor(2.5454, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4836 tensor(2.5450, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4837 tensor(2.5445, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4838 tensor(2.5441, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4839 tensor(2.5437, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4840 tensor(2.5433, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4841 tensor(2.5429, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4842 tensor(2.5425, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4843 tensor(2.5421, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 4844 tensor(2.5417, device='cuda:0', grad_fn=<MeanBackward0>)
# ...
# iteration 8912 tensor(1.4928, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8913 tensor(1.4927, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8914 tensor(1.4926, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8915 tensor(1.4924, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8916 tensor(1.4923, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8917 tensor(1.4922, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8918 tensor(1.4921, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8919 tensor(1.4920, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8920 tensor(1.4918, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8921 tensor(1.4917, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8922 tensor(1.4916, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8923 tensor(1.4915, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8924 tensor(1.4914, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8925 tensor(1.4912, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8926 tensor(1.4911, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8927 tensor(1.4910, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8928 tensor(1.4909, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8929 tensor(1.4908, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8930 tensor(1.4906, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8931 tensor(1.4905, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8932 tensor(1.4904, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8933 tensor(1.4903, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8934 tensor(1.4902, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8935 tensor(1.4901, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8936 tensor(1.4899, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8937 tensor(1.4898, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8938 tensor(1.4897, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8939 tensor(1.4896, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8940 tensor(1.4895, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8941 tensor(1.4894, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8942 tensor(1.4892, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8943 tensor(1.4891, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8944 tensor(1.4890, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8945 tensor(1.4889, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8946 tensor(1.4888, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8947 tensor(1.4886, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8948 tensor(1.4885, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8949 tensor(1.4884, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8950 tensor(1.4883, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8951 tensor(1.4882, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8952 tensor(1.4881, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8953 tensor(1.4879, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8954 tensor(1.4878, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8955 tensor(1.4843, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8956 tensor(1.4842, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8957 tensor(1.4841, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8958 tensor(1.4840, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8959 tensor(1.4839, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8960 tensor(1.4837, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8961 tensor(1.4836, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8962 tensor(1.4835, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8963 tensor(1.4834, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8964 tensor(1.4833, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8965 tensor(1.4832, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8966 tensor(1.4830, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8967 tensor(1.4829, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8968 tensor(1.4828, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8969 tensor(1.4827, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8970 tensor(1.4826, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8971 tensor(1.4825, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8972 tensor(1.4823, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8973 tensor(1.4822, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8974 tensor(1.4821, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8975 tensor(1.4820, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8976 tensor(1.4819, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8977 tensor(1.4817, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8978 tensor(1.4816, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8979 tensor(1.4815, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8980 tensor(1.4814, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8981 tensor(1.4813, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8982 tensor(1.4812, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8983 tensor(1.4810, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8984 tensor(1.4809, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8985 tensor(1.4808, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8986 tensor(1.4807, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8987 tensor(1.4806, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8988 tensor(1.4805, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8989 tensor(1.4803, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8990 tensor(1.4802, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8991 tensor(1.4801, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8992 tensor(1.4800, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8993 tensor(1.4799, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8994 tensor(1.4798, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8995 tensor(1.4797, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8996 tensor(1.4795, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8997 tensor(1.4794, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8998 tensor(1.4793, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 8999 tensor(1.4792, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 9000 tensor(1.4791, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9001 tensor(1.4790, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9002 tensor(1.4788, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9003 tensor(1.4787, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9004 tensor(1.4786, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9005 tensor(1.4785, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9006 tensor(1.4784, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9007 tensor(1.4783, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9008 tensor(1.4781, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9009 tensor(1.4780, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9010 tensor(1.4779, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9011 tensor(1.4778, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9012 tensor(1.4777, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9013 tensor(1.4776, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9014 tensor(1.4775, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9015 tensor(1.4773, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9016 tensor(1.4772, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9017 tensor(1.4771, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9018 tensor(1.4770, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9019 tensor(1.4769, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9020 tensor(1.4768, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9021 tensor(1.4766, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9022 tensor(1.4765, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9023 tensor(1.4764, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9024 tensor(1.4763, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9025 tensor(1.4762, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9026 tensor(1.4761, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9027 tensor(1.4760, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9028 tensor(1.4758, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9029 tensor(1.4757, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9030 tensor(1.4756, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9031 tensor(1.4755, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9032 tensor(1.4754, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9033 tensor(1.4753, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9034 tensor(1.4752, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9035 tensor(1.4750, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9036 tensor(1.4749, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9037 tensor(1.4748, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9038 tensor(1.4747, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9039 tensor(1.4746, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9040 tensor(1.4745, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9041 tensor(1.4744, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9042 tensor(1.4742, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9043 tensor(1.4741, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9044 tensor(1.4740, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9045 tensor(1.4739, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9046 tensor(1.4738, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9047 tensor(1.4737, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9048 tensor(1.4736, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9049 tensor(1.4734, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9050 tensor(1.4733, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9051 tensor(1.4732, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9052 tensor(1.4731, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9053 tensor(1.4730, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9054 tensor(1.4729, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9055 tensor(1.4728, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9056 tensor(1.4726, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9057 tensor(1.4725, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9058 tensor(1.4724, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9059 tensor(1.4723, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9060 tensor(1.4722, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9061 tensor(1.4721, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9062 tensor(1.4720, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9063 tensor(1.4719, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9064 tensor(1.4717, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9065 tensor(1.4716, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9066 tensor(1.4715, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9067 tensor(1.4714, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9068 tensor(1.4713, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9069 tensor(1.4712, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9070 tensor(1.4711, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9071 tensor(1.4709, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9072 tensor(1.4708, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9073 tensor(1.4707, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9074 tensor(1.4706, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9075 tensor(1.4705, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9076 tensor(1.4704, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9077 tensor(1.4703, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9078 tensor(1.4702, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9079 tensor(1.4700, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9080 tensor(1.4699, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9081 tensor(1.4698, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9082 tensor(1.4697, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9083 tensor(1.4696, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9084 tensor(1.4695, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9085 tensor(1.4694, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9086 tensor(1.4692, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9087 tensor(1.4691, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9088 tensor(1.4690, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9089 tensor(1.4689, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9090 tensor(1.4688, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9091 tensor(1.4687, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9092 tensor(1.4686, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9093 tensor(1.4685, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9094 tensor(1.4683, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9095 tensor(1.4682, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9096 tensor(1.4681, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9097 tensor(1.4680, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9098 tensor(1.4679, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9099 tensor(1.4678, device='cuda:0', grad_fn=<MeanBackward0>)
# saving a training checkpoint in drive
# iteration 9100 tensor(1.4677, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9101 tensor(1.4676, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9102 tensor(1.4674, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9103 tensor(1.4673, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9104 tensor(1.4672, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9105 tensor(1.4671, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9106 tensor(1.4670, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9107 tensor(1.4669, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9108 tensor(1.4668, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9109 tensor(1.4667, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9110 tensor(1.4665, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9111 tensor(1.4664, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9112 tensor(1.4663, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9113 tensor(1.4662, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9114 tensor(1.4661, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9115 tensor(1.4660, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9116 tensor(1.4659, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9117 tensor(1.4658, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9118 tensor(1.4656, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9119 tensor(1.4655, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9120 tensor(1.4654, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9121 tensor(1.4653, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9122 tensor(1.4652, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9123 tensor(1.4651, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9124 tensor(1.4650, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9125 tensor(1.4649, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9126 tensor(1.4647, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9127 tensor(1.4627, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9128 tensor(1.4625, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9129 tensor(1.4624, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9130 tensor(1.4623, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9131 tensor(1.4622, device='cuda:0', grad_fn=<MeanBackward0>)
# iteration 9132 tensor(1.4621, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
random.seed(12345)
mixed,target,labels = get_validation_set(3)

# %%
for i in range(len(mixed)):
  audio_input = torch.unsqueeze(mixed[i],dim=0).to(device="cuda")
  print(audio_input.shape)
  label_input = labels[i]
  output_target = torch.unsqueeze(target[i],dim=0).to(device="cuda")

  audio_embedding = model.get_text_embedding([label_input,label_input],use_tensor=True).to(device="cuda")[0]
  output = rete.model(audio_input,audio_embedding)
  validation_loss = rete.loss(output,output_target)
  print(validation_loss)


  torchaudio.save("./mixed.mp3",audio_input.to(device="cpu")[0],32000)
  torchaudio.save("./res.mp3",output.to(device="cpu")[0],32000)
  torchaudio.save("./target.mp3",output_target.to(device="cpu")[0],32000)
  break

# %%
res = output.to(device="cpu")
target = target.to(device="cpu")
batch = batch.to(device="cpu")
print(labels[1])
torchaudio.save("./mixed.mp3",batch[1],32000)
torchaudio.save("./res.mp3",res[1],32000)
torchaudio.save("./target.mp3",target[1],32000)
# Out:
# Bark Domestic animals pets Dog Animal

# %%
from pydub import AudioSegment
import os
list_files = os.listdir("./download")
for elem in list_files:
  sound = AudioSegment.from_file(f"./download/{elem}")
  sound = sound.set_channels(1)
  sound.export(f"./download_mono/{elem}", format="mp3")
